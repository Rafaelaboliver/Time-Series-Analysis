# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
#from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.linear_model import LinearRegression
#from statsmodels.tsa.tsatools import detrend
from pandas import DataFrame, Series
import matplotlib.pylab as plt
#import seaborn as sns
import pandas as pd
import numpy as np
import datetime
import os
import io

# %matplotlib inline
np.set_printoptions(precision=3 , suppress= True)

# %%
def import_station_data(station_name, folder_path, file_format='txt'):
    
    #joining the folder path with the name of the station to get all the wanted ones
    file_path = os.path.join(folder_path, f'{station_name}.{file_format}')
    
    #selecting the name of the columns that will be used to do the analysis
    columns_name = ['YYMMMDD', '__east(m)']
    
    #checking the file format and sending an error message if the format doesn't match
    if file_format == 'txt':
        station_data = pd.read_csv(file_path, usecols=columns_name, delimiter='\s+')
    else:
        raise ValueError (f'{file_format}: unsupported file format.')
    
    
    try:
        #initial setting as datetime format, index, column names and time period
        station_data['YYMMMDD'] = pd.to_datetime(station_data['YYMMMDD'], format='%y%b%d', errors='coerce')
        station_data.set_index('YYMMMDD', inplace = True)
        station_data = station_data.rename(columns={'__east(m)':f'{station_name}_east(m)'})
        station_data = station_data.loc['2011-01-15':'2018-07-15']
        
    except ValueError as e:
        print(f"Erro to import {station_name}: {e}")
        station_data = None
    

    
#PAREI AQUI!!
def linear_detrend(station_data):
    
    #getting the linear model to substract from the original time series:
    x = np.arange(len(station_data)).reshape(-1,1)
    y = station_data[f'{station_name}_east(m)'].reshape(-1,1)
    
    linear_model = LinearRegression().fit(x,y)
    regression_line = linear_model.predict(x)
    
    detrended_values = y.flatten() - regression_line.flattenn()
    #detrended_values = station_data[f'{station_name}_east(m)'].values - regression_line.flattenn()

    
    return station_data

station_names = ['acom', 'barc', 'brse', 'cafv', 'canv', 
                 'citt', 'kope', 'koe2', 'mogg', 'mpra', 
                 'odez', 'pord', 'port', 'rovr', 'sapp',
                 'tarv', 'trie', 'trvs'
                ]
folder_path = '/home/rafaela/internship/time_series/Time-Series-Analysis/Cansiglio Plateau + Classical Karst/'

station_data_dict = {}

#importing the stations and storing in the dictionare 'station_data_dic'
for station_name in station_names:
    station_data = import_station_data(station_name, folder_path, file_format='txt')
    station_data_dict[station_name] = station_data

for station_name, station_data in station_data_dict.items():
    print(f'{station_name.upper()}:\n{station_data}\n')
# Out:
# ACOM:
#             acom_east(m)
# YYMMMDD
# 2011-01-15      0.808130
# 2011-01-16      0.808262
# 2011-01-17      0.806723
# 2011-01-18      0.806866
# 2011-01-19      0.807964
# ...                  ...
# 2018-07-11      0.965803
# 2018-07-12      0.967535
# 2018-07-13      0.967369
# 2018-07-14      0.966661
# 2018-07-15      0.966177
#
# [2680 rows x 1 columns]
#
# BARC:
#             barc_east(m)
# YYMMMDD
# 2011-01-15     -0.185527
# 2011-01-16     -0.185496
# 2011-01-17     -0.186973
# 2011-01-18     -0.185291
# 2011-01-19     -0.184679
# ...                  ...
# 2012-06-26     -0.160704
# 2012-06-27     -0.159194
# 2012-06-28     -0.158764
# 2012-06-29     -0.159055
# 2012-06-30     -0.159056
#
# [522 rows x 1 columns]
#
# BRSE:
#             brse_east(m)
# YYMMMDD
# 2011-01-15     -0.590748
# 2011-01-16     -0.590841
# 2011-01-17     -0.592690
# 2011-01-18     -0.592770
# 2011-01-19     -0.590746
# ...                  ...
# 2018-07-11     -0.438925
# 2018-07-12     -0.437142
# 2018-07-13     -0.438114
# 2018-07-14     -0.439656
# 2018-07-15     -0.439180
#
# [2575 rows x 1 columns]
#
# CAFV:
#             cafv_east(m)
# YYMMMDD
# 2011-03-03      0.265158
# 2011-03-04      0.264473
# 2011-03-05      0.263649
# 2011-03-06      0.264599
# 2011-03-07      0.265411
# ...                  ...
# 2018-07-11      0.414755
# 2018-07-12      0.414348
# 2018-07-13      0.416747
# 2018-07-14      0.413928
# 2018-07-15      0.417889
#
# [2294 rows x 1 columns]
#
# CANV:
#             canv_east(m)
# YYMMMDD
# 2011-01-15      0.511474
# 2011-01-16      0.512056
# 2011-01-17      0.509941
# 2011-01-18      0.510445
# 2011-01-19      0.510449
# ...                  ...
# 2018-07-11      0.654737
# 2018-07-12      0.656873
# 2018-07-13      0.656140
# 2018-07-14      0.655291
# 2018-07-15      0.655690
#
# [2593 rows x 1 columns]
#
# CITT:
#             citt_east(m)
# YYMMMDD
# 2011-01-16     -0.077985
# 2011-01-17     -0.079634
# 2011-01-18     -0.079274
# 2011-01-19     -0.077785
# 2011-01-20     -0.079280
# ...                  ...
# 2018-07-05      0.082126
# 2018-07-06      0.082658
# 2018-07-10      0.084429
# 2018-07-11      0.083126
# 2018-07-12      0.083492
#
# [2061 rows x 1 columns]
#
# KOPE:
#             kope_east(m)
# YYMMMDD
# 2011-01-15      0.689561
# 2011-01-16      0.690957
# 2011-01-17      0.689411
# 2011-01-18      0.690189
# 2011-01-19      0.691691
# ...                  ...
# 2018-07-11      0.879316
# 2018-07-12      0.879798
# 2018-07-13      0.882255
# 2018-07-14      0.881320
# 2018-07-15      0.880847
#
# [2541 rows x 1 columns]
#
# KOE2:
#             koe2_east(m)
# YYMMMDD
# 2011-01-15      0.567426
# 2011-01-16      0.566281
# 2011-01-17      0.564457
# 2011-01-18      0.565295
# 2011-01-19      0.567116
# ...                  ...
# 2016-10-02      0.684718
# 2016-10-03      0.684435
# 2016-10-04      0.684108
# 2016-10-05      0.684364
# 2016-10-06      0.683895
#
# [2091 rows x 1 columns]
#
# MOGG:
#             mogg_east(m)
# YYMMMDD
# 2011-01-15     -0.791088
# 2011-01-16     -0.789750
# 2011-01-17     -0.791311
# 2011-01-18     -0.791146
# 2011-01-19     -0.789792
# ...                  ...
# 2012-06-26     -0.761659
# 2012-06-27     -0.761938
# 2012-06-28     -0.760480
# 2012-06-29     -0.760138
# 2012-06-30     -0.760629
#
# [523 rows x 1 columns]
#
# MPRA:
#             mpra_east(m)
# YYMMMDD
# 2011-01-15      0.126120
# 2011-01-16      0.126736
# 2011-01-17      0.125353
# 2011-01-18      0.125557
# 2011-01-19      0.126959
# ...                  ...
# 2018-07-11      0.279312
# 2018-07-12      0.280467
# 2018-07-13      0.281665
# 2018-07-14      0.282317
# 2018-07-15      0.281199
#
# [2667 rows x 1 columns]
#
# ODEZ:
#             odez_east(m)
# YYMMMDD
# 2011-03-03     -0.423405
# 2011-03-04     -0.424593
# 2011-03-05     -0.424607
# 2011-03-06     -0.424189
# 2011-03-07     -0.422235
# ...                  ...
# 2018-07-11     -0.272176
# 2018-07-12     -0.272684
# 2018-07-13     -0.271860
# 2018-07-14     -0.271710
# 2018-07-15     -0.272570
#
# [2502 rows x 1 columns]
#
# PORD:
#             pord_east(m)
# YYMMMDD
# 2011-01-15     -0.426474
# 2011-01-16     -0.426743
# 2011-01-17     -0.428277
# 2011-01-18     -0.427432
# 2011-01-19     -0.425891
# ...                  ...
# 2018-07-11     -0.272596
# 2018-07-12     -0.271376
# 2018-07-13     -0.272706
# 2018-07-14     -0.271336
# 2018-07-15     -0.271645
#
# [2709 rows x 1 columns]
#
# PORT:
#             port_east(m)
# YYMMMDD
# 2011-01-15      0.158195
# 2011-01-16      0.160081
# 2011-01-17      0.157168
# 2011-01-18      0.158048
# 2011-01-19      0.159577
# ...                  ...
# 2017-10-24      0.302240
# 2017-10-25      0.303114
# 2017-10-26      0.302632
# 2017-10-27      0.302781
# 2017-10-28      0.302574
#
# [2325 rows x 1 columns]
#
# ROVR:
#             rovr_east(m)
# YYMMMDD
# 2011-01-15     -0.242591
# 2011-01-16     -0.241759
# 2011-01-17     -0.243946
# 2011-01-18     -0.242945
# 2011-01-19     -0.241445
# ...                  ...
# 2018-01-27     -0.099935
# 2018-01-28     -0.099587
# 2018-01-29     -0.099971
# 2018-01-30     -0.100924
# 2018-01-31     -0.100274
#
# [2337 rows x 1 columns]
#
# SAPP:
#             sapp_east(m)
# YYMMMDD
# 2011-01-17     -0.962007
# 2011-01-18     -0.961984
# 2011-01-19     -0.960740
# 2011-01-20     -0.962324
# 2011-01-21     -0.962956
# ...                  ...
# 2018-07-06     -0.808119
# 2018-07-09     -0.805337
# 2018-07-10     -0.804876
# 2018-07-11     -0.805339
# 2018-07-12     -0.805123
#
# [2466 rows x 1 columns]
#
# TARV:
#             tarv_east(m)
# YYMMMDD
# 2011-01-15     -0.099592
# 2011-01-16     -0.099132
# 2011-01-17     -0.100807
# 2011-01-18     -0.100880
# 2011-01-19     -0.099347
# ...                  ...
# 2012-06-26     -0.071745
# 2012-06-27     -0.071424
# 2012-06-28     -0.068432
# 2012-06-29     -0.069549
# 2012-06-30     -0.067320
#
# [519 rows x 1 columns]
#
# TRIE:
#             trie_east(m)
# YYMMMDD
# 2011-01-15     -0.468270
# 2011-01-16     -0.468008
# 2011-01-17     -0.470291
# 2011-01-18     -0.468805
# 2011-01-19     -0.467608
# ...                  ...
# 2018-07-11     -0.311754
# 2018-07-12     -0.309847
# 2018-07-13     -0.309565
# 2018-07-14     -0.309624
# 2018-07-15     -0.309652
#
# [2665 rows x 1 columns]
#
# TRVS:
#             trvs_east(m)
# YYMMMDD
# 2011-01-15      0.739852
# 2011-01-16      0.740157
# 2011-01-17      0.738094
# 2011-01-18      0.738742
# 2011-01-19      0.740338
# ...                  ...
# 2018-07-03      0.897748
# 2018-07-04      0.894537
# 2018-07-06      0.896146
# 2018-07-11      0.896787
# 2018-07-12      0.896241
#
# [2153 rows x 1 columns]
